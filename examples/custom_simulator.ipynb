# %% [markdown]
# # Custom Simulator Walkthrough\n\nThis notebook runs the custom NumPy-based simulator on a transpiled circuit.

# %%
from qiskit import transpile\nfrom fp_qgpu import simple00, simulator_own

# %%
qc = simple00()\nqc_transpiled = transpile(qc, basis_gates=['u', 'cx'])\npsi = simulator_own(qc_transpiled)\npsi

# %%
abs(psi) ** 2
