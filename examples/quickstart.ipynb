# %% [markdown]
# # FP-QGPU Quickstart\n\nThis notebook shows a minimal end-to-end flow using the reference simulator.

# %%
from fp_qgpu import simple00, simulator_mock

# %%
qc = simple00()\nqc.measure_all()\ncounts, statevector = simulator_mock(qc, shots=1024, seed=42)\ncounts

# %%
statevector
