# %% [markdown]
# # GHZ State Example\n\nThis notebook builds a GHZ-style circuit and compares simulation outputs.

# %%
from qiskit import transpile\nfrom fp_qgpu import ghz_test, simulator_mock, simulator_own

# %%
qc = ghz_test(3)\nstate_custom = simulator_own(qc)\ncounts_ref, state_ref = simulator_mock(qc, shots=1024, seed=7)

# %%
state_custom

# %%
state_ref
